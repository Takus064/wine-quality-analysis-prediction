# %% [markdown]
# ## **THƯ VIỆN**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
import math
from imblearn.combine import SMOTETomek
from sklearn.model_selection import ( RandomizedSearchCV,GridSearchCV,
                                    train_test_split)

from sklearn.metrics import (f1_score, precision_score, recall_score,
                            classification_report, make_scorer,
                            average_precision_score, precision_recall_curve, confusion_matrix)

from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler,MinMaxScaler, RobustScaler

# %% [markdown]
# ## **1. Phân tích dữ liệu khám phá ban đầu (EDA) và tiền xử lí dữ liệu:**

# %%
df = pd.read_csv(r"C:\Users\Hp\Downloads\Data_for_Tieu luan mon hoc Ung dung AI\winequality-red.csv", delimiter=';')
# delimiter để ngăn cách giữa các thực thể
# trong dataframe ( ở dâyd trong file csv đc ngăn cách bằng ";")
# chỉnh lại type thành dạng float để đồng nhất hóa đơn vị
df['quality'] = df['quality'].astype("float")
df = pd.DataFrame(df)
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4      5.0
# 1         9.8      5.0
# 2         9.8      5.0
# 3         9.8      6.0
# 4         9.4      5.0
# ...       ...      ...
# 1594     10.5      5.0
# 1595     11.2      6.0
# 1596     11.0      6.0
# 1597     10.2      5.0
# 1598     11.0      6.0
#
# [1599 rows x 12 columns]

# %% [markdown]
# ## KIỂM TRA RA DỮ LIỆU TỔNG THỂ

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
# check summary statistics of the data
df.describe().T
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.270976   0.194801  0.00000   0.0900
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# quality               1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max
# fixed acidity          7.90000   9.200000   15.90000
# volatile acidity       0.52000   0.640000    1.58000
# citric acid            0.26000   0.420000    1.00000
# residual sugar         2.20000   2.600000   15.50000
# chlorides              0.07900   0.090000    0.61100
# free sulfur dioxide   14.00000  21.000000   72.00000
# total sulfur dioxide  38.00000  62.000000  289.00000
# density                0.99675   0.997835    1.00369
# pH                     3.31000   3.400000    4.01000
# sulphates              0.62000   0.730000    2.00000
# alcohol               10.20000  11.100000   14.90000
# quality                6.00000   6.000000    8.00000

# %%
# check null values
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df["quality"].unique()
# Out:
# array([5., 6., 7., 4., 8., 3.])

# %% [markdown]
# ## KIỂM TRA CHI TIẾT CÁC CỘT

# %%
def Column_Info(column):
    for column in df.columns:
        print("Chi tiết",column,"column")
    # count Unique Values
        print("\nĐếm số giá trị distinct là: ",df[column].nunique())

    # Get AttributesAttributes of Column
        print("\nPhân bổ giá trị trong cột là:\n")
        print(df[column].value_counts())
        print('-'*50)

# %%
Column_Info(df.columns)
# Out:
# Chi tiết fixed acidity column
#
# Đếm số giá trị distinct là:  96
#
# Phân bổ giá trị trong cột là:
#
# fixed acidity
# 7.2     67
# 7.1     57
# 7.8     53
# 7.5     52
# 7.0     50
#         ..
# 13.5     1
# 13.8     1
# 13.4     1
# 4.7      1
# 5.5      1
# Name: count, Length: 96, dtype: int64
# --------------------------------------------------
# Chi tiết volatile acidity column
#
# Đếm số giá trị distinct là:  143
#
# Phân bổ giá trị trong cột là:
#
# volatile acidity
# 0.600    47
# 0.500    46
# 0.430    43
# 0.590    39
# 0.360    38
#          ..
# 1.035     1
# 0.565     1
# 1.130     1
# 1.115     1
# 1.090     1
# Name: count, Length: 143, dtype: int64
# --------------------------------------------------
# Chi tiết citric acid column
#
# Đếm số giá trị distinct là:  80
#
# Phân bổ giá trị trong cột là:
#
# citric acid
# 0.00    132
# 0.49     68
# 0.24     51
# 0.02     50
# 0.26     38
#        ...
# 0.72      1
# 0.62      1
# 0.75      1
# 1.00      1
# 0.78      1
# Name: count, Length: 80, dtype: int64
# --------------------------------------------------
# Chi tiết residual sugar column
#
# Đếm số giá trị distinct là:  91
#
# Phân bổ giá trị trong cột là:
#
# residual sugar
# 2.00     156
# 2.20     131
# 1.80     129
# 2.10     128
# 1.90     117
#         ...
# 4.25       1
# 2.85       1
# 3.45       1
# 2.35       1
# 13.90      1
# Name: count, Length: 91, dtype: int64
# --------------------------------------------------
# Chi tiết chlorides column
#
# Đếm số giá trị distinct là:  153
#
# Phân bổ giá trị trong cột là:
#
# chlorides
# 0.080    66
# 0.074    55
# 0.076    51
# 0.078    51
# 0.084    49
#          ..
# 0.108     1
# 0.148     1
# 0.143     1
# 0.222     1
# 0.230     1
# Name: count, Length: 153, dtype: int64
# --------------------------------------------------
# Chi tiết free sulfur dioxide column
#
# Đếm số giá trị distinct là:  60
#
# Phân bổ giá trị trong cột là:
#
# free sulfur dioxide
# 6.0     138
# 5.0     104
# 10.0     79
# 15.0     78
# 12.0     75
# 7.0      71
# 9.0      62
# 16.0     61
# 17.0     60
# 11.0     59
# 13.0     57
# 8.0      56
# 14.0     50
# 3.0      49
# 18.0     46
# 4.0      41
# 21.0     41
# 19.0     39
# 24.0     34
# 26.0     32
# 23.0     32
# 20.0     30
# 27.0     29
# 25.0     24
# 29.0     23
# 28.0     23
# 22.0     22
# 32.0     22
# 31.0     20
# 34.0     18
# 30.0     16
# 35.0     15
# 36.0     11
# 33.0     11
# 38.0      9
# 41.0      7
# 40.0      6
# 39.0      5
# 48.0      4
# 51.0      4
# 45.0      3
# 1.0       3
# 43.0      3
# 42.0      3
# 52.0      3
# 37.0      3
# 68.0      2
# 55.0      2
# 50.0      2
# 37.5      2
# 53.0      1
# 72.0      1
# 57.0      1
# 47.0      1
# 5.5       1
# 2.0       1
# 46.0      1
# 54.0      1
# 40.5      1
# 66.0      1
# Name: count, dtype: int64
# --------------------------------------------------
# Chi tiết total sulfur dioxide column
#
# Đếm số giá trị distinct là:  144
#
# Phân bổ giá trị trong cột là:
#
# total sulfur dioxide
# 28.0     43
# 24.0     36
# 15.0     35
# 18.0     35
# 23.0     34
#          ..
# 139.0     1
# 149.0     1
# 152.0     1
# 155.0     1
# 165.0     1
# Name: count, Length: 144, dtype: int64
# --------------------------------------------------
# Chi tiết density column
#
# Đếm số giá trị distinct là:  436
#
# Phân bổ giá trị trong cột là:
#
# density
# 0.99720    36
# 0.99680    35
# 0.99760    35
# 0.99800    29
# 0.99620    28
#            ..
# 0.99684     1
# 0.99764     1
# 0.99473     1
# 0.99320     1
# 0.99651     1
# Name: count, Length: 436, dtype: int64
# --------------------------------------------------
# Chi tiết pH column
#
# Đếm số giá trị distinct là:  89
#
# Phân bổ giá trị trong cột là:
#
# pH
# 3.30    57
# 3.36    56
# 3.26    53
# 3.38    48
# 3.39    48
#         ..
# 3.75     1
# 2.74     1
# 3.70     1
# 3.85     1
# 2.90     1
# Name: count, Length: 89, dtype: int64
# --------------------------------------------------
# Chi tiết sulphates column
#
# Đếm số giá trị distinct là:  96
#
# Phân bổ giá trị trong cột là:
#
# sulphates
# 0.60    69
# 0.58    68
# 0.54    68
# 0.62    61
# 0.56    60
#         ..
# 1.00     1
# 1.59     1
# 0.33     1
# 1.26     1
# 1.01     1
# Name: count, Length: 96, dtype: int64
# --------------------------------------------------
# Chi tiết alcohol column
#
# Đếm số giá trị distinct là:  65
#
# Phân bổ giá trị trong cột là:
#
# alcohol
# 9.500000     139
# 9.400000     103
# 9.800000      78
# 9.200000      72
# 10.000000     67
#             ...
# 9.950000       1
# 9.233333       1
# 9.250000       1
# 9.050000       1
# 10.750000      1
# Name: count, Length: 65, dtype: int64
# --------------------------------------------------
# Chi tiết quality column
#
# Đếm số giá trị distinct là:  6
#
# Phân bổ giá trị trong cột là:
#
# quality
# 5.0    681
# 6.0    638
# 7.0    199
# 4.0     53
# 8.0     18
# 3.0     10
# Name: count, dtype: int64
# --------------------------------------------------

# %%
plot_df = df.copy()

n_cols = 4
n_rows = math.ceil((len(plot_df.columns) - 1) / n_cols)  # -1 ko tính  'quality'

fig, axes = plt.subplots(n_rows, n_cols, figsize=(24, 8 * n_rows))
fig.tight_layout(pad=5.0)

axes = axes.flatten()

quality_values = sorted(plot_df['quality'].unique())
colors = plt.cm.rainbow(np.linspace(0, 1, len(quality_values)))

for i, col in enumerate(plot_df.columns):
    if col != 'quality':
        sns.histplot(data=plot_df, x=col, ax=axes[i], kde=True)

        for q, c in zip(quality_values, colors):
            subset = plot_df[plot_df['quality'] == q]
            if not subset.empty:
                axes[i].axvline(subset[col].mean(), color=c, linestyle='--',
                                label=f'Quality {q}')

        axes[i].set_xlabel(col, fontsize=14, fontweight='bold')
        axes[i].set_ylabel('Count', fontsize=14, fontweight='bold')

        axes[i].set_title(f'Distribution of {col}', fontsize=16, fontweight='bold')

        axes[i].tick_params(labelsize=12)
        axes[i].legend(fontsize=10, title='Quality', title_fontsize=12)

for j in range(len(plot_df.columns) - 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()

fig.suptitle('Distribution of Dataset', fontsize=20, fontweight='bold', y=1.02)

plt.show()

# %% [markdown]
# T**ừ biểu đồ phân bố giá trị của các thuộc tính ta có thể thấy :**
#
# ==> Các thuộc tính 'fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide' và 'density' có phân bố dữ liệu không đều, có nhiều giá trị nằm ở phía bên trái của biểu đồ, điều này có thể làm cho mô hình dễ bị nhiễu bởi các giá trị ngoại lai.
#
# -- Fixed acidity:
#
# Phân phối lệch phải, với đỉnh chính ở khoảng 6-8.
# Rượu chất lượng cao có xu hướng có độ axit cố định cao hơn.
#
# -- Volatile acidity:
#
# Phân phối khá cân đối, với đỉnh ở khoảng 0.3-0.4.
# Rượu chất lượng thấp có xu hướng có độ axit bay hơi cao hơn.
#
# -- Citric acid:
#
# Phân phối đa phương thức với nhiều đỉnh.
# Rượu chất lượng cao có xu hướng có hàm lượng axit citric cao hơn.
#
# -- Residual sugar:
#
# Phân phối lệch phải mạnh, với đa số mẫu có lượng đường dư thấp (dưới 5).
# Không có sự khác biệt rõ ràng giữa các mức chất lượng.
#
# -- Chlorides:
#
# Phân phối lệch phải, tập trung chủ yếu ở khoảng 0.05-0.1.
# Rượu chất lượng cao có xu hướng có hàm lượng clorua thấp hơn.
#
# -- Free sulfur dioxide và Total sulfur dioxide:
#
# Cả hai đều có phân phối lệch phải.
#
# Rượu chất lượng cao có xu hướng có hàm lượng sulfur dioxide tự do và tổng số thấp hơn.
#
# -- Density:
#
# Phân phối gần như chuẩn, tập trung quanh 0.995-1.000.
# Không có sự khác biệt rõ ràng giữa các mức chất lượng.
#
# -- pH:
#
# Phân phối gần như chuẩn, tập trung quanh 3.0-3.4.
# Không có sự khác biệt rõ ràng giữa các mức chất lượng.
#
#
# -- Sulphates:
#
# Phân phối lệch phải, với đỉnh ở khoảng 0.5.
# Rượu chất lượng cao có xu hướng có hàm lượng sulphate cao hơn.
#
# -- Alcohol:
#
# Phân phối lệch phải nhẹ.
# Rượu chất lượng cao có xu hướng có nồng độ cồn cao hơn.
#
# **KẾT LUẬN:**
#
# -- Nhiều đặc trưng có mối tương quan với chất lượng rượu, đặc biệt là volatile acidity, citric acid, chlorides, sulfur dioxide, sulphates và alcohol.
#
# -- Phần lớn các đặc trưng có phân phối lệch, cho thấy sự không đồng đều trong dữ liệu.
#
# Bộ dữ liệu có vẻ khá đồng nhất với 1599 mẫu cho mỗi đặc trưng, không có giá trị null.

# %%
plt.figure(figsize=(10,8))
sns.histplot(df['quality'], kde=True, bins=6)
plt.title('Distribution of Quality')
plt.xlabel("Wine Quality")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# **Từ biểu đồ phân phối chất lượng rượu này, ta có thể rút ra một số nhận xét quan trọng:**
#
# Phân phối chất lượng rượu có phân phối chuẩn không cân bằng, với đa số mẫu tập trung ở mức trung bình.
# Đây là phân phối đa phương thức, với hai đỉnh chính rõ rệt.
#
#
# **Các mức chất lượng chính:**
#
# Hai mức chất lượng phổ biến nhất là 5 và 6, chiếm phần lớn các mẫu.
# Mức chất lượng 5 có số lượng mẫu cao nhất, tiếp theo là mức 6.
#
# -- Chất lượng trung bình:
#
# Phần lớn rượu trong bộ dữ liệu có chất lượng trung bình, tập trung ở mức 5-6.
#
# -- Chất lượng cao và thấp:
#
# Có rất ít mẫu rượu chất lượng rất cao (mức 7-8) hoặc rất thấp (mức 3-4).
# Số lượng mẫu giảm đáng kể ở hai đầu của thang đánh giá.
#
# -- Khoảng chất lượng:
#
# Thang đánh giá chất lượng từ 3 đến 8, không có mẫu nào ở mức 1-2 hoặc 9-10.
#
# -- Tính không cân đối:
#
# Phân phối hơi lệch phải, với đuôi dài hơn về phía chất lượng cao.
#
# **Kết luận:**
#
# Bộ dữ liệu này chủ yếu bao gồm rượu có chất lượng trung bình.
#
# Rượu chất lượng xuất sắc hoặc kém chất lượng đều hiếm gặp trong bộ dữ liệu.
#
# Việc phân loại rượu thành các nhóm chất lượng (thấp, trung bình, cao) có thể hữu ích cho phân tích và mô hình hóa.
#
# ==> Sự mất cân đối trong phân phối có thể ảnh hưởng đến việc xây dựng mô hình dự đoán
#
# **==> Ta phải chia nhỏ giá trị chất lượng rượu theo (0: Tệ, 1: Trung bình, 2: Tốt) để mô hình học tốt hơn**

# %%
corr = plot_df.corr()

fig, ax = plt.subplots(figsize=(20, 18))
sns.heatmap(corr, vmin=-1, vmax=1, center=0, annot=True, fmt='.2f',
            cmap='coolwarm', annot_kws={'fontsize': 8, 'fontweight': 'bold'}, cbar=False)

ax.tick_params(left=False, bottom=False)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=10)
ax.set_yticklabels(ax.get_yticklabels(), fontsize=10)

plt.title('Heatmap cho các biến liên quan ', fontsize=16, pad=20)
plt.tight_layout()
plt.show()

# %%
corr_quality = corr['quality']
corr_quality = corr_quality.abs().sort_values(ascending=False)
print('Correlation of Wine Quality":')
print(corr_quality)
# Out:
# Correlation of Wine Quality":
# quality                 1.000000
# alcohol                 0.476166
# volatile acidity        0.390558
# sulphates               0.251397
# citric acid             0.226373
# total sulfur dioxide    0.185100
# density                 0.174919
# chlorides               0.128907
# fixed acidity           0.124052
# pH                      0.057731
# free sulfur dioxide     0.050656
# residual sugar          0.013732
# Name: quality, dtype: float64

# %% [markdown]
# -- Nhiều đặc trưng có mối tương quan với chất lượng rượu, đặc biệt là volatile acidity, citric acid, chlorides, sulfur dioxide, sulphates và alcohol.
#
# -- => Các biến liên quan có tương quan khá vừa (correlation < 0.8) vậy ta nên chọn hết để build model

# %% [markdown]
# CHECK OUTLIERS USING IQR METHOD

# %%
outliers_col = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide','total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol']

plt.figure(figsize=(15, 10))
for i, feature in enumerate(outliers_col, 1):
    plt.subplot(5, 5, i)
    sns.boxplot(x=df[feature])
    plt.title(f'Boxplot of {feature}')
plt.tight_layout()
plt.show()

# %%
# Tính IQR cho từng cột
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1

# Xác định khoảng cho phép
lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)

# Lọc các cột có outliers
df_outliers = df[((df < lower_bound) | (df > upper_bound)).any(axis=1)]

# Hiển thị các cột có outliers
print("Các cột có outliers:", df_outliers.columns.tolist())
# Out:
# Các cột có outliers: ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality']

# %% [markdown]
# => Ta sẽ giữ outliers do dataset này khá bé đồng nhất và không có giá trị null nên ta sẽ giữ lại"""

# %% [markdown]
# ## **2. Phân tích đặc trưng và tạo đặc trưng mới: FEATURE ENGINEERING**

# %% [markdown]
# Ta sẽ gộp lại những feature có tương quan với nhau lại để giúp mô hình học tốt hơn

# %%
plt.figure(figsize=(10,8))
sns.histplot(plot_df['alcohol'], kde=True, bins=6)
plt.title('Distribution of alcohol')
plt.xlabel(" alcohol")
plt.ylabel("Count")
plt.show()

# %%
df['free_sulfur_ratio'] = df['free sulfur dioxide'] / df['total sulfur dioxide']
# Tỷ lệ giữa sulfur dioxide tự do và tổng sulfur dioxide.

df['bound_sulfur'] = df['total sulfur dioxide'] - df['free sulfur dioxide']
# Lượng sulfur dioxide liên kết.

df['fixed_volatile_acidity_interaction'] = df['fixed acidity'] * df['volatile acidity']
#Tương tác giữa độ axit cố định và độ axit bay hơi.

df['citric_residual_sugar_interaction'] = df['citric acid'] * df['residual sugar']
#Tương tác giữa axit citric và đường dư.( do có cùng tương quan với density)


q = df['alcohol'].quantile([0.2, 0.4, 0.6, 0.8])
#Phân loại nồng độ cồn thành các nhóm ( rất thấp, thấp, trung , cao,rất cao) vì có sự phân loại khá rõ.
# gán nhãn
df['alcohol_bins'] = pd.cut(df['alcohol'], bins=[-np.inf, q[0.2], q[0.4], q[0.6], q[0.8], np.inf], labels=[0, 1, 2, 3, 4])

df['quality_bins'] = pd.cut(df['quality'],bins = [-np.inf, 4, 6, np.inf],labels = [0,1,2])
# Phân loại chất lượng thành 3 loại ( tệ trung bình  tốt)

# %% [markdown]
# ## **4. Chọn đặc trưng:**

# %% [markdown]
# Kiểm tra lại correlation sau khi thêm biến mới

# %%
corr = df.corr()

fig, ax = plt.subplots(figsize=(20, 18))
sns.heatmap(corr, vmin=-1, vmax=1, center=0, annot=True, fmt='.2f',
            cmap='coolwarm', annot_kws={'fontsize': 8, 'fontweight': 'bold'}, cbar=False)

ax.tick_params(left=False, bottom=False)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=10)
ax.set_yticklabels(ax.get_yticklabels(), fontsize=10)

plt.title('Heatmap cho các biến liên quan ', fontsize=16, pad=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# Loại những cặp có correlation cao

# %%
# viết function để tự độngđộng hóa
def correlation(corr, threshold):
    corr_pair = [] # Set of all the names of correlated columns
    for i in range(len(corr.columns)):
        for j in range(i):
            if abs(corr.iloc[i, j]) > threshold :
                corr_pair.append((corr.columns[i], corr.columns[j], corr.iloc[i,j]))
    return corr_pair

# %%
correlated_features = correlation(corr, 0.7) # các features cần bị loại bỏ

# %%
drop_features = []
for i ,j, k in correlated_features:
    drop_features.append(j)
drop_features = list(set(drop_features))
drop_features
# Out:
# ['total sulfur dioxide',
#  'volatile acidity',
#  'citric acid',
#  'quality',
#  'residual sugar',
#  'alcohol']

# %%
df_features = df.drop(drop_features, axis=1)
df_features
# Out:
#       fixed acidity  chlorides  free sulfur dioxide  density    pH  sulphates  \
# 0               7.4      0.076                 11.0  0.99780  3.51       0.56
# 1               7.8      0.098                 25.0  0.99680  3.20       0.68
# 2               7.8      0.092                 15.0  0.99700  3.26       0.65
# 3              11.2      0.075                 17.0  0.99800  3.16       0.58
# 4               7.4      0.076                 11.0  0.99780  3.51       0.56
# ...             ...        ...                  ...      ...   ...        ...
# 1594            6.2      0.090                 32.0  0.99490  3.45       0.58
# 1595            5.9      0.062                 39.0  0.99512  3.52       0.76
# 1596            6.3      0.076                 29.0  0.99574  3.42       0.75
# 1597            5.9      0.075                 32.0  0.99547  3.57       0.71
# 1598            6.0      0.067                 18.0  0.99549  3.39       0.66
#
#       free_sulfur_ratio  bound_sulfur  fixed_volatile_acidity_interaction  \
# 0              0.323529          23.0                              5.1800
# 1              0.373134          42.0                              6.8640
# 2              0.277778          39.0                              5.9280
# 3              0.283333          43.0                              3.1360
# 4              0.323529          23.0                              5.1800
# ...                 ...           ...                                 ...
# 1594           0.727273          12.0                              3.7200
# 1595           0.764706          12.0                              3.2450
# 1596           0.725000          11.0                              3.2130
# 1597           0.727273          12.0                              3.8055
# 1598           0.428571          24.0                              1.8600
#
#       citric_residual_sugar_interaction alcohol_bins quality_bins
# 0                                 0.000            0            1
# 1                                 0.000            1            1
# 2                                 0.092            1            1
# 3                                 1.064            1            1
# 4                                 0.000            0            1
# ...                                 ...          ...          ...
# 1594                              0.160            2            1
# 1595                              0.220            3            1
# 1596                              0.299            3            1
# 1597                              0.240            2            1
# 1598                              1.692            3            1
#
# [1599 rows x 12 columns]

# %%
corr = df_features.corr()

fig, ax = plt.subplots(figsize=(20, 18))
sns.heatmap(corr, vmin=-1, vmax=1, center=0, annot=True, fmt='.2f',
            cmap='coolwarm', annot_kws={'fontsize': 8, 'fontweight': 'bold'}, cbar=False)

ax.tick_params(left=False, bottom=False)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=10)
ax.set_yticklabels(ax.get_yticklabels(), fontsize=10)

plt.title('Heatmap cho các biến liên quan ', fontsize=16, pad=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **==> Ta xử lý xong dataset**

# %% [markdown]
# ## **5. Chia dữ liệu:**

# %%
X, y = df_features.drop(['quality_bins'], axis=1), df_features['quality_bins']
y.value_counts(normalize = True)
# Out:
# quality_bins
# 1    0.824891
# 2    0.135710
# 0    0.039400
# Name: proportion, dtype: float64

# %% [markdown]
# => Tập y có sự mất cần bằng khá lớn, ta dùng kỹ thuật SMOTE để xủ lý

# %%
# Apply SMOTE
smote = SMOTETomek(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# %%
y_resampled.value_counts(normalize = True)
print(X_resampled.shape)
# Out:
# (3923, 11)

# %% [markdown]
# => Tập y đã có sự cân bằng giữa các giá trị

# %%
scaler = RobustScaler()# để giảm ảnh hưởng của outlier

# %%
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, stratify = y_resampled , random_state=42)
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## **6. Xây dựng mô hình cơ bản:**

# %%
dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred = dt.predict(X_test)

# %%
accuracy = dt.score(X_test, y_test)
print(f"Accuracy   {accuracy}")
print(f"Classification Report ")
print(classification_report(y_test, y_pred))

conf_matrix = confusion_matrix(y_test, y_pred)
print(conf_matrix)
# Out:
# Accuracy   0.8942675159235669
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92       261
#            1       0.87      0.86      0.86       261
#            2       0.90      0.89      0.89       263
#
#     accuracy                           0.89       785
#    macro avg       0.89      0.89      0.89       785
# weighted avg       0.89      0.89      0.89       785
#
# [[244   8   9]
#  [ 19 224  18]
#  [  4  25 234]]

# %% [markdown]
# **Accuracy: 0.894 (~89.43%)**
#
# **Hiệu suất theo từng lớp:**
#
# Nhãn 0:
#
# Precision: 0.91: Trong số tất cả các dự đoán cho nhãn 0, 91% là đúng.
#
# Recall: 0.93: Trong số tất cả các trường hợp thực tế thuộc nhãn 0, mô
# hình dự đoán đúng 93%.
#
# F1-Score: 0.92: F1 là sự cân bằng giữa Precision và Recall.
#
# Nhãn 1:
# Precision: 0.87: Trong số các dự đoán cho nhãn 1, 87% là đúng.
#
# Recall: 0.86: Mô hình dự đoán đúng 86% trong số tất cả các trường hợp thực tế là nhãn 1.
#
# F1-Score: 0.86: F1-Score của nhãn 1 là 0.86, cân bằng giữa Precision và Recall.
#
# Nhãn 2:
#
# Precision: 0.90: Trong số tất cả các dự đoán cho nhãn 2, 90% là đúng.
#
# Recall: 0.89: Mô hình dự đoán đúng 89% trong số tất cả các trường hợp thực tế thuộc nhãn 2.
#
# F1-Score: 0.89: F1-Score của nhãn 2 là 0.89.
#
# **=> TÓM LẠI**
#
# Mô hình hoạt động khá tốt, với độ chính xác tổng thể là 89%.
#
# Mô hình hoạt động tốt nhất cho nhãn 0, với Precision và Recall cao (91% và 93%).
#
# Mức độ dự đoán đúng của mô hình cho nhãn 1 và nhãn 2 cũng khá cao, nhưng có một số trường hợp dự đoán nhầm lẫn giữa nhãn 1 và nhãn 2 (dự đoán nhãn 2 thành nhãn 1 và ngược lại).

# %% [markdown]
# ***=> Ta cần ưu tiên hơn vể sự cân bằng giữa precision và recall để cho lấy được kết quả sát nhất so với tập mẫu***

# %% [markdown]
# ## => Ta sẽ áp dụng kỹ thuật Decision Tree Pruning và sử dụng RandomSearchCV để so sánh và tìm ra mô hình tốt nhất trong 2 cách tối ưu model này

# %% [markdown]
# ## **7. Kỹ thuật DecisionTree Pruning**

# %%
dt_test = DecisionTreeClassifier(random_state=42) # tạo 1 model để test

# %%
path = dt.cost_complexity_pruning_path(X_train, y_train)
ccp_alphas, impurities = path.ccp_alphas, path.impurities
# vòng lặp for sẽ đi tìm ra các giá trị ccp_alpha tối ưu nhất cho mô hình cây quyết định
dt_collection = []
for ccp_alpha in ccp_alphas:
    dt_test = DecisionTreeClassifier(random_state=42, ccp_alpha=ccp_alpha)
    dt_test.fit(X_train, y_train)
    dt_collection.append(dt_test)

# %%
test_scores = [dt_test.score(X_test, y_test) for dt_test in dt_collection]

# %%
optimal_alpha = ccp_alphas[test_scores.index(max(test_scores))]
print(f"alpha tốt nhất: {optimal_alpha}")
# Out:
# alpha tốt nhất: 0.0002941609060155904

# %%
pruned_dt = DecisionTreeClassifier(random_state=42, ccp_alpha=optimal_alpha)
pruned_dt.fit(X_train, y_train)
print(f"Điểm trước khi cắt tỉa:{dt.score(X_test,y_test):.4f}")
print(f"Điểm sau khi đã cắt tỉa: {pruned_dt.score(X_test, y_test):.4f}")
pruned_pred = pruned_dt.predict(X_test)
# Out:
# Điểm trước khi cắt tỉa:0.8943
# Điểm sau khi đã cắt tỉa: 0.8955

# %%
accuracy = pruned_dt.score(X_test, y_test)
print(f"Accuracy   {accuracy}")
print(f"Classification Report ")
print(classification_report(y_test, pruned_pred))

conf_matrix = confusion_matrix(y_test, pruned_pred)
print(conf_matrix)
# Out:
# Accuracy   0.8955414012738854
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.92      0.93      0.93       261
#            1       0.87      0.86      0.87       261
#            2       0.90      0.89      0.89       263
#
#     accuracy                           0.90       785
#    macro avg       0.90      0.90      0.90       785
# weighted avg       0.90      0.90      0.90       785
#
# [[244   8   9]
#  [ 18 225  18]
#  [  4  25 234]]

# %% [markdown]
# **1. So sánh về Accuracy:**
#
# Trước pruning: 0.8943 (89.43%)
#
# Sau pruning: 0.8955 (89.55%)
#
# Nhận xét: Độ chính xác đã tăng nhẹ từ 89.43% lên 89.55%, cho thấy pruning giúp loại bỏ bớt các nhánh không cần thiết trong mô hình và làm cho nó tổng quát hơn.
#
# **2. So sánh Precision, Recall và F1-Score:**
#
# ***Nhãn 0:***
#
# Precision:
#
# Trước pruning: 0.91
#
# Sau pruning: 0.92
#
# Recall:
#
# Trước pruning: 0.93
#
# Sau pruning: 0.93
#
# F1-Score:
#
# Trước pruning: 0.92
#
# Sau pruning: 0.93
#
# Nhận xét: Precision và F1-Score cho nhãn 0 đã tăng nhẹ, nhưng Recall giữ nguyên. Điều này cho thấy mô hình sau pruning hoạt động tốt hơn ở việc phân loại đúng các mẫu thuộc nhãn 0.
#
# ***Nhãn 1:***
#
# Precision:
#
# Trước pruning: 0.87
#
# Sau pruning: 0.87
#
# Recall:
#
# Trước pruning: 0.86
#
# Sau pruning: 0.86
#
# F1-Score:
#
# Trước pruning: 0.86
#
# Sau pruning: 0.87
#
# Nhận xét: Mặc dù Precision và Recall không thay đổi, F1-Score đã được cải thiện từ 0.86 lên 0.87 sau khi pruning. Điều này cho thấy mô hình đã cân bằng tốt hơn giữa Precision và Recall cho nhãn 1.
#
# ***Nhãn 2:***
#
# Precision:
#
# Trước pruning: 0.90
#
# Sau pruning: 0.90
#
# Recall:
#
# Trước pruning: 0.89
#
# Sau pruning: 0.89
#
# F1-Score:
#
# Trước pruning: 0.89
#
# Sau pruning: 0.89
#
# Nhận xét: Đối với nhãn 2, các chỉ số Precision, Recall, và F1-Score đều giữ nguyên. Điều này cho thấy mô hình không có sự thay đổi nhiều đối với các dự đoán cho nhãn này sau khi pruning.

# %% [markdown]
# **Kết luận:**
#
# -- Pruning đã giúp mô hình cải thiện một chút về hiệu suất tổng thể, đặc biệt là Precision và F1-Score cho nhãn 0 và nhãn 1.
#
# -- Số lượng dự đoán đúng cho nhãn 1 đã tăng lên, trong khi các chỉ số cho nhãn 0 và nhãn 2 phần lớn giữ nguyên.
#
# -- Độ chính xác tổng thể chỉ tăng nhẹ, nhưng pruning giúp mô hình trở nên tổng quát hơn và tránh overfitting.

# %% [markdown]
# ## **8. Điều chỉnh siêu tham số: FINE TUNNING VỚI RandomSearchCV**

# %%
params = {
    'max_depth': range(2,20,1),
    'min_samples_leaf': range(1,15,1),
    'min_samples_split': range(2,15,1),
    'criterion': ["gini", "entropy"],
    'splitter':['best','random']
}

# %%
random_search = RandomizedSearchCV(
    estimator=pruned_dt,
    param_distributions=params,
    n_iter=100,
    scoring='accuracy',
    cv=6,
    random_state=42,
    n_jobs=-1
    )


random_search.fit(X_train, y_train)
pred = random_search.predict(X_test)
best_model = random_search.best_estimator_
best_params_random = random_search.best_params_
print(f"Best Parameters (Random Search): {best_params_random}")
print(f"Best Model  (Random Search): {best_model}")
# Out:
# Best Parameters (Random Search): {'splitter': 'best', 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_depth': 15, 'criterion': 'entropy'}
# Best Model  (Random Search): DecisionTreeClassifier(ccp_alpha=0.0002941609060155904, criterion='entropy',
#                        max_depth=15, random_state=42)

# %% [markdown]
# => Vậy model tối ưu của ta sẽ có những tham số, criterion='entropy', max_depth=15, min_samples_leaf=1,random_state=42
#
# tuy nhiên, để có được sự cân bằng giữa precision và recall , ta nên dùng criterion 'gini', và min_samples_leaf= 1

# %% [markdown]
# ## **9. Model tối ưu**

# %%
dt_best = DecisionTreeClassifier(ccp_alpha=0.0002941609060155904, criterion='gini',
                       max_depth=15, random_state=42, min_samples_leaf=1,  min_samples_split=2)

# %%
dt_best.fit(X_train, y_train)
predict = dt_best.predict(X_test)

# %%
accuracy = dt_best.score(X_test, y_test)
print(f"Accuracy for the best tree model  {accuracy}")
print(f"Classification Report ")
print(classification_report(y_test, predict))

conf_matrix = confusion_matrix(y_test, predict)
print(conf_matrix)
# Out:
# Accuracy for the best tree model  0.9057324840764331
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93       261
#            1       0.90      0.85      0.88       261
#            2       0.91      0.91      0.91       263
#
#     accuracy                           0.91       785
#    macro avg       0.91      0.91      0.91       785
# weighted avg       0.91      0.91      0.91       785
#
# [[249   7   5]
#  [ 19 223  19]
#  [  6  18 239]]

# %% [markdown]
# ==> Ta có mô hình tối ưu nhất

# %% [markdown]
# ***1. So sánh về Accuracy:***
#
# Sau pruning: 0.8955 (89.55%)
#
# Model tối ưu: 0.9057 (90.57%)
#
# Nhận xét: Độ chính xác của mô hình sau khi áp dụng RandomSearchCV và pruning tăng thêm khoảng 1% so với mô hình sau pruning thông thường. Điều này cho thấy RandomSearchCV đã giúp tìm được bộ tham số tối ưu để cải thiện hiệu suất của mô hình.
#
# ***2. So sánh Precision, Recall, và F1-Score:***
#
# ***Nhãn 0:***
#
# Precision:
#
# Sau pruning: 0.92
#
# Model tối ưu: 0.91
#
# Recall:
#
# Sau pruning: 0.93
#
# Model tối ưu: 0.95
#
# F1-Score:
#
# Sau pruning: 0.93
#
# Model tối ưu: 0.93
#
# Nhận xét: Mặc dù Precision giảm nhẹ từ 0.92 xuống 0.91, nhưng Recall của nhãn 0 tăng đáng kể từ 0.93 lên 0.95. Điều này có nghĩa là mô hình tối ưu nhận diện chính xác hơn các mẫu thuộc nhãn 0.
#
# ***Nhãn 1:***
#
# Precision:
#
# Sau pruning: 0.87
#
# Model tối ưu: 0.90
#
# Recall:
#
# Sau pruning: 0.86
#
# Model tối ưu: 0.85
#
# F1-Score:
#
# Sau pruning: 0.87
#
# Model tối ưu: 0.88
#
# Nhận xét: Precision của nhãn 1 tăng từ 0.87 lên 0.90, trong khi Recall giảm nhẹ từ 0.86 xuống 0.85. Tuy nhiên, F1-Score cho nhãn 1 vẫn cải thiện từ 0.87 lên 0.88, cho thấy mô hình tối ưu giúp cân bằng tốt hơn giữa Precision và Recall.
#
# ***Nhãn 2:***
# Precision:
#
# Sau pruning: 0.90
#
# Model tối ưu: 0.91
#
# Recall:
#
# Sau pruning: 0.89
#
# Model tối ưu: 0.91
#
# F1-Score:
#
# Sau pruning: 0.89
#
# Model tối ưu: 0.91
#
# Nhận xét: Đối với nhãn 2, tất cả các chỉ số (Precision, Recall, F1-Score) đều được cải thiện, với F1-Score tăng từ 0.89 lên 0.91. Điều này cho thấy mô hình tối ưu dự đoán nhãn 2 chính xác hơn so với mô hình pruning ban đầu.

# %% [markdown]
# ***Kết luận:***
#
# -- Model tối ưu sau RandomSearchCV và pruning có độ chính xác và hiệu suất cao hơn so với mô hình chỉ pruning. Đặc biệt, Precision, Recall, và F1-Score của tất cả các nhãn đều được cải thiện hoặc duy trì tốt hơn.
#
# -- Số mẫu dự đoán đúng cho các nhãn cũng tăng lên, đặc biệt là nhãn 0 và nhãn 2, giúp mô hình dự đoán chính xác hơn cho các nhãn này.

# %% [markdown]
# **==> TA XÂY DỰNG ĐƯỢC 1 MÔ HÌNH TỐI ƯU NHẤT SỬ DỤNG DecisionTreeClassifier**

# %% [markdown]
# ## **10.Những features đặc trưng nhất**

# %%
# Get feature importances
importances = dt_best.feature_importances_

# Create a DataFrame
feature_importances = pd.DataFrame({'feature': X.columns, 'importance': importances})
feature_importances = feature_importances.sort_values('importance', ascending=False)

# Print feature importances
print(feature_importances)


# Visualize feature importances using a bar plot
sns.barplot(x='importance', y='feature', data=feature_importances)
plt.title('Feature Importances')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.show()
# Out:
#                                feature  importance
# 10                        alcohol_bins    0.271040
# 5                            sulphates    0.213063
# 8   fixed_volatile_acidity_interaction    0.103753
# 7                         bound_sulfur    0.087057
# 4                                   pH    0.077585
# 6                    free_sulfur_ratio    0.057768
# 0                        fixed acidity    0.050674
# 3                              density    0.045936
# 1                            chlorides    0.036980
# 9    citric_residual_sugar_interaction    0.032865
# 2                  free sulfur dioxide    0.023278

# %%
selected_features = feature_importances[feature_importances['importance'] > 0.1]['feature'].tolist()

# %%
print("Những features quan trọng nhất", selected_features)
# Out:
# Những features quan trọng nhất ['alcohol_bins', 'sulphates', 'fixed_volatile_acidity_interaction']

# %% [markdown]
# ## **11. Màn hình chức năng**

# %%
import joblib as jb
jb.dump(dt_best, 'wine_quality_model.pkl')
jb.dump(scaler, 'scaler.pkl')
# Out:
# ['scaler.pkl']

# %%
df_features.to_csv("df_features.csv")

# %% [markdown]
# ## => Ta tạo ra 1 bản copy của file dataset đã được xử lý để so sánh kết quả mô hình

# %%
user_interface = df_features.copy()
user_interface.head()
# Out:
#    fixed acidity  chlorides  free sulfur dioxide  density    pH  sulphates  \
# 0            7.4      0.076                 11.0   0.9978  3.51       0.56
# 1            7.8      0.098                 25.0   0.9968  3.20       0.68
# 2            7.8      0.092                 15.0   0.9970  3.26       0.65
# 3           11.2      0.075                 17.0   0.9980  3.16       0.58
# 4            7.4      0.076                 11.0   0.9978  3.51       0.56
#
#    free_sulfur_ratio  bound_sulfur  fixed_volatile_acidity_interaction  \
# 0           0.323529          23.0                               5.180
# 1           0.373134          42.0                               6.864
# 2           0.277778          39.0                               5.928
# 3           0.283333          43.0                               3.136
# 4           0.323529          23.0                               5.180
#
#    citric_residual_sugar_interaction alcohol_bins quality_bins
# 0                              0.000            0            1
# 1                              0.000            1            1
# 2                              0.092            1            1
# 3                              1.064            1            1
# 4                              0.000            0            1
